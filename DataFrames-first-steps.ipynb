# %%
df = sqlContext.read.json("posts.jsons")

# %% [markdown]
# ### Can you answer why is it taking so long?

# %%
df.printSchema()
# Out:
# root
#  |-- AcceptedAnswerId: string (nullable = true)
#  |-- AnswerCount: string (nullable = true)
#  |-- Body: string (nullable = true)
#  |-- ClosedDate: string (nullable = true)
#  |-- CommentCount: string (nullable = true)
#  |-- CommunityOwnedDate: string (nullable = true)
#  |-- CreationDate: string (nullable = true)
#  |-- FavoriteCount: string (nullable = true)
#  |-- Id: string (nullable = true)
#  |-- LastActivityDate: string (nullable = true)
#  |-- LastEditDate: string (nullable = true)
#  |-- LastEditorDisplayName: string (nullable = true)
#  |-- LastEditorUserId: string (nullable = true)
#  |-- OwnerDisplayName: string (nullable = true)
#  |-- OwnerUserId: string (nullable = true)
#  |-- ParentId: string (nullable = true)
#  |-- PostTypeId: string (nullable = true)
#  |-- Score: string (nullable = true)
#  |-- Tags: string (nullable = true)
#  |-- Title: string (nullable = true)
#  |-- ViewCount: string (nullable = true)

# %%
# would you like to feel like you're at home?
df.limit(100).toPandas()
# Out:
#    AcceptedAnswerId AnswerCount  \
# 0              None        None
# 1              None        None
# 2              None        None
# 3              None        None
# 4              None        None
# 5              None        None
# 6              None        None
# 7              None        None
# 8            686992           3
# 9            686935           5
# 10             None        None
# 11             None        None
# 12             None        None
# 13           686957           3
# 14             None        None
# 15           687622           3
# 16             None        None
# 17             None           3
# 18             None        None
# 19             None        None
# 20             None        None
# 21             None        None
# 22             None        None
# 23             None        None
# 24             None        None
# 25             None        None
# 26           687038           3
# 27             None        None
# 28             None           1
# 29             None        None
# ..              ...         ...
# 70           687008           1
# 71             None        None
# 72           687080           1
# 73             None        None
# 74             None        None
# 75             None        None
# 76             None        None
# 77             None        None
# 78             None        None
# 79             None        None
# 80             None        None
# 81           687023           6
# 82             None        None
# 83             None        None
# 84             None        None
# 85          1339268           3
# 86             None        None
# 87             None        None
# 88             None        None
# 89             None        None
# 90             None        None
# 91             None        None
# 92             None        None
# 93             None        None
# 94             None        None
# 95             None        None
# 96             None        None
# 97           687042           6
# 98             None        None
# 99             None        None
#
#                                                  Body  \
# 0   <p>You can paint graphics into your own off-sc...
# 1   <p>If you don't link against it, you are in th...
# 2   <p>With GPL I think the only way out is to wra...
# 3   <pre><code>// A Gorgon class - For the love of...
# 4   <p>Axis2 does not support Spring web services ...
# 5   <p>If you can, I'd recommend writing to the Ev...
# 6   <p>You get your browser's language for your bu...
# 7   <pre><code>Do\n\n love();\n\n honor();\n\n che...
# 8   <p>Usually not calling Dispose indicates a pos...
# 9   <p>This is a snippet from my <code>index.php</...
# 10  <p>I think the common concensus would be use a...
# 11  <p>You can use the usual <code>acquire; try { ...
# 12  <p>I return a small class called ResultSet fro...
# 13  <p>Is there any documentation on exactly how e...
# 14  <p>You should detect the <a href="http://msdn....
# 15  <p>If curly brackets ('{' and '}') are used in...
# 16  <p>I'm not sure if you can use it <em>from</em...
# 17  <p>I'm using Perl's File::Find module to scan ...
# 18  <p>You don't want to do this. AJAX is nice and...
# 19  <p>list/ditionary constructor (i.e. table type...
# 20  <p>Simple answer - whenever your SQL is not al...
# 21  <pre><code>// Java-ish pseudocode\npublic Happ...
# 22  <p>Thanks for that last tip Sam. I had a dialo...
# 23  <p>The question is what is worse:</p>\n\n<ul>\...
# 24  <p>Maybe this could help: <a href="http://www....
# 25  <p>InvokeRequired's cost depends on which clas...
# 26  <p>I'm trying to dig into the XML for a VBPROJ...
# 27  <p>You can go in to your application propertie...
# 28  <p>Is there a way to get SSIS (&lt;cough>hatei...
# 29  <p>I believe the basic install (from the SubVe...
# ..                                                ...
# 70  <pre><code>//window is an HWND\nLPWSTR path = ...
# 71  <p>Assuming the select ID from where the names...
# 72  <p>I have a problem to solve that I think will...
# 73  <p>I'd start by decoupling the data table righ...
# 74  <p>Unfortunately, you must manually clean up f...
# 75  <p>Consider implementing MVP (model view prese...
# 76  <p><strong>Main problem:</strong> </p>\n\n<p>F...
# 77  <p>It is normally provided by the browser and ...
# 78  <p>I think you are looking for something like ...
# 79  <p>Use mod rewrite .htaccess\nThis should pres...
# 80  <p>Joshua Bloch has proposed adding a mechanis...
# 81  <p>I am creating temporary files from a bash s...
# 82  <p>Have you tried logging your view's width an...
# 83  <p>If all you want is authorization, start wit...
# 84  <p>The output window itself is truncating your...
# 85  <p>Oracle pads values in char columns so if I ...
# 86  <p>Are you talking about in SQL Server Managem...
# 87  <p>Question:  Are you certain you have Java 6 ...
# 88  <p>You could set a "<a href="http://tldp.org/L...
# 89  <blockquote>\n  <p>Creating an instance of the...
# 90  <p>The data is all there, but management studi...
# 91  <p>You don't have to bother removing those tmp...
# 92  <p>Here's some code that'll convert an integer...
# 93  <p>If you use LoadControl() to load the contro...
# 94  <p>maybe this <a href="http://stackoverflow.co...
# 95  <p>You should only use CHAR for strings that w...
# 96  <p>You want to use the <a href="http://www.gnu...
# 97  <p>I really want to use hashsets in my program...
# 98  <p>You haven't mentioned only returning the JS...
# 99  <p>I ended up using that code for IE and faili...
#
#                  ClosedDate CommentCount       CommunityOwnedDate  \
# 0                      None            4                     None
# 1                      None            3                     None
# 2                      None            3                     None
# 3                      None            0  2009-03-26T18:05:09.430
# 4                      None            0                     None
# 5                      None            1                     None
# 6                      None            2                     None
# 7                      None            0  2009-03-26T18:05:49.727
# 8                      None            1                     None
# 9                      None            1                     None
# 10                     None            5                     None
# 11                     None            0                     None
# 12                     None            3                     None
# 13                     None            0                     None
# 14                     None            0                     None
# 15                     None            2                     None
# 16                     None            0                     None
# 17                     None            1                     None
# 18                     None            0                     None
# 19                     None            3                     None
# 20                     None            0                     None
# 21                     None            3  2009-03-26T18:08:50.110
# 22                     None            0                     None
# 23                     None           11                     None
# 24                     None            0                     None
# 25                     None            0                     None
# 26                     None            0                     None
# 27                     None            0                     None
# 28                     None            4                     None
# 29                     None            0                     None
# ..                      ...          ...                      ...
# 70                     None            0                     None
# 71                     None            0                     None
# 72  2014-05-22T02:23:36.087            3                     None
# 73                     None            1                     None
# 74                     None            2                     None
# 75                     None            0                     None
# 76                     None            3                     None
# 77                     None            2                     None
# 78                     None            0                     None
# 79                     None            0                     None
# 80                     None            2                     None
# 22    ...                     None             None                Echilon
# 23    ...               Grauenwolf           102937             Grauenwolf
# 24    ...                     None             None                    Seb
# 25    ...                     None             None            Reed Copsey
# 26    ...                     None             None                Danny G
# 27    ...               windfinder            45581             windfinder
# 28    ...                     None             None                   None
# 29    ...                     None             None                  Frank
# ..    ...                      ...              ...                    ...
# 70    ...           Kevin Montrose            80572         Kevin Montrose
# 71    ...                     None             None                    Seb
# 72    ...               Daniel Lew           321731            Simon Gibbs
# 73    ...                     None             None                   Josh
# 74    ...                     None            18706            Luke Francl
# 75    ...                     None             None                 Hrvoje
# 76    ...           Brian R. Bondy             3153         Brian R. Bondy
# 77    ...                     None            63550            ChristopheD
# 78    ...                     None             None          Kevin Crowell
# 79    ...                     None             None               AB Kolan
# 80    ...                     None             None   Kjetil &#216;degaard
# 81    ...                     None             2907                  skinp
# 82    ...                     None             None           Wim Haanstra
# 83    ...                     None             None           Frank Farmer
# 84    ...                     None             None                  Clyde
# 85    ...                     Toto           972463                   Toto
# 86    ...                     None             None                  Chris
# 87    ...                     None             None               Steve L.
# 88    ...             Paul Tomblin             3333           Paul Tomblin
# 89    ...                     None             None            Jason Baker
# 90    ...                     None             None                    Jim
# 91    ...                     None             None        Mykola Golubyev
# 92    ...                     Erik              356                   Erik
# 93    ...                     None             None               AndreasN
# 94    ...                     None             None                    JSC
# 95    ...                     None             None          Kevin Crowell
# 96    ...           Brian Campbell               -1         Brian Campbell
# 97    ...                     None             None                  Brian
# 98    ...                     None             None                   Troy
# 99    ...                     None             None           craigmoliver
#
#    OwnerUserId ParentId PostTypeId Score  \
# 0         4725   686822          2     2
# 1        13986   686857          2     2
# 2        29639   686857          2     0
# 3         7862   184618          2    16
# 4        28946   216779          2     1
# 5        83260   680200          2     4
# 6        76583   686905          2    11
# 7        79856   686216          2     2
# 8        14074     None          1     2
# 9        55794     None          1     0
# 10       54420   686896          2     1
# 11        4725   686897          2    10
# 12       19032   686896          2     5
# 13        4653     None          1     2
# 14       23234   683132          2     2
# 15       43496     None          1     7
# 16        1666   686611          2     1
# 17       34903     None          1     2
# 18       16417   686924          2     8
# 19        3153   686931          2     4
# 20       31641   686724          2    11
# 21       78743   686216          2     9
# 22       30512   211971          2     2
# 23        5274   686724          2   118
# 24       76583   686894          2     0
# 25       65358   686929          2     2
# 26       76302     None          1     5
# 27       45581   686893          2     3
# 28       15751     None          1     0
# 29       18196   686892          2     0
# ..         ...      ...        ...   ...
# 70       80572     None          1     2
# 71       76583   686965          2     0
# 72       13935     None          1    18
# 73       26160   686960          2     0
# 74       17965   686852          2    63
# 75        1407   686960          2     0
# 76        3153   687001          2     5
# 77       81179   686905          2    21
# 78       81193   686980          2     2
# 79       64497   686855          2     0
# 80       74185   686897          2     4
# 81        2907     None          1    43
# 82       69313   686910          2     1
# 83       82769   686185          2     1
# 84         945   686996          2     7
# 85       26699     None          1     2
# 86        6744   686996          2     5
# 87       63013   686893          2     1
# 88        3333   687014          2    33
# 89        2147   685253          2     0
# 90         681   686996          2     0
# 91       54684   687014          2    -2
# 92       16942   686847          2     9
# 93       24821   686726          2     3
# 94       37311   686753          2     0
# 95       81193   687018          2     1
# 96       69755   687014          2    13
# 97       18192     None          1    18
# 98        5047   686753          2     3
# 99       12252   679067          2     0
#
#                                                  Tags  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                  <c#><unit-testing>
# 9                                 <php><jquery><ajax>
# 10                                               None
# 11                                               None
# 12                                               None
# 13                               <c#><multithreading>
# 14                                               None
# 15                                      <syntax><lua>
# 16                                               None
# 17               <perl><symlink><dangling><file-find>
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26  <.net><asp.net><visual-studio><visual-studio-2...
# 27                                               None
# 28                                        <sql><ssis>
# 29                                               None
# ..                                                ...
# 70                                        <c><winapi>
# 71                                               None
# 72                                      <open-source>
# 73                                               None
# 74                                               None
# 75                                               None
# 76                                               None
# 77                                               None
# 78                                               None
# 79                                               None
# 80                                               None
# 81                     <linux><bash><temporary-files>
# 82                                               None
# 83                                               None
# 84                                               None
# 85                               <java><oracle><jdbc>
# 86                                               None
# 87                                               None
# 88                                               None
# 89                                               None
# 90                                               None
# 91                                               None
# 92                                               None
# 93                                               None
# 94                                               None
# 95                                               None
# 96                                               None
# 97                     <c#><.net><visual-studio-2005>
# 98                                               None
# 99                                               None
#
#                                                 Title ViewCount
# 0                                                None      None
# 1                                                None      None
# 2                                                None      None
# 3                                                None      None
# 4                                                None      None
# 5                                                None      None
# 6                                                None      None
# 7                                                None      None
# 8   How to make sure that Dispose method was calle...      1651
# 9          To use PHP templates or jQuery AJAX calls?      1456
# 10                                               None      None
# 11                                               None      None
# 12                                               None      None
# 13              How expensive is the IsInvokeRequired       476
# 14                                               None      None
# 15                    Are curly brackets used in Lua?      6067
# 16                                               None      None
# 17  Why doesn't File::Find handle my dangling syml...      2059
# 18                                               None      None
# 19                                               None      None
# 20                                               None      None
# 21                                               None      None
# 22                                               None      None
# 23                                               None      None
# 24                                               None      None
# 25                                               None      None
# 26                                    VBPROJ / CSPROJ      2941
# 27                                               None      None
# 28              SSIS - Suggest types from destination       423
# 29                                               None      None
# ..                                                ...       ...
# 70  QueryFullProcessImageName failing with valid H...      3100
# 71                                               None      None
# 72  Paying open source project members for bug fix...       569
# 73                                               None      None
# 74                                               None      None
# 75                                               None      None
# 76                                               None      None
# 77                                               None      None
# 78                                               None      None
# 79                                               None      None
# 80                                               None      None
# 81  Removing created temp files in unexpected bash...     26708
# 82                                               None      None
# 83                                               None      None
# 84                                               None      None
# 85  How to use Oracle jdbc driver fixedString prop...      2554
# 86                                               None      None
# 87                                               None      None
# 88                                               None      None
# 89                                               None      None
# 90                                               None      None
# 91                                               None      None
# 92                                               None      None
# 93                                               None      None
# 94                                               None      None
# 95                                               None      None
# 96                                               None      None
# 97       Using HashSet in C# 2.0, compatible with 3.5     17131
# 98                                               None      None
# 99                                               None      None
#
# [100 rows x 21 columns]

# %%
# if not, you can use spark way to do roughly the same
df.show()
# Out:
# +----------------+-----------+--------------------+----------+------------+------------------+--------------------+-------------+------+--------------------+--------------------+---------------------+----------------+--------------------+-----------+--------+----------+-----+--------------------+--------------------+---------+
# |AcceptedAnswerId|AnswerCount|                Body|ClosedDate|CommentCount|CommunityOwnedDate|        CreationDate|FavoriteCount|    Id|    LastActivityDate|        LastEditDate|LastEditorDisplayName|LastEditorUserId|    OwnerDisplayName|OwnerUserId|ParentId|PostTypeId|Score|                Tags|               Title|ViewCount|
# |            null|       null|<p>check this fro...|      null|           0|              null|2008-10-29T13:15:...|         null|246754|2008-10-29T13:15:...|                null|                 null|            null|Joachim Kerschbaumer|      20227|  246636|         2|    3|                null|                null|     null|
# |            null|       null|<p>A full tutoria...|      null|           1|              null|2008-10-29T13:16:...|         null|246756|2008-10-29T13:16:...|                null|                 null|            null|             Gamecat|      18061|  246723|         2|    2|                null|                null|     null|
# |            null|       null|<p>There is a Cod...|      null|           0|              null|2008-10-29T13:17:...|         null|246757|2008-10-29T13:17:...|                null|                 null|            null|      GalacticCowboy|      29638|  246520|         2|    2|                null|                null|     null|
# |            null|       null|<p>Maybe java.io....|      null|           1|              null|2008-10-29T13:17:...|         null|246758|2008-10-29T13:17:...|                null|                 null|            null|        johanneslink|      32352|  246744|         2|    2|                null|                null|     null|
# |            null|       null|<p>Have you taken...|      null|           1|              null|2008-10-29T13:18:...|         null|246759|2008-10-29T13:18:...|                null|                 null|            null|                null|      17640|  246744|         2|    4|                null|                null|     null|
# |          246796|          3|<p>In an UML comp...|      null|           0|              null|2008-10-29T13:18:...|         null|246760|2009-10-21T15:01:...|2009-10-21T15:01:...|                 null|            5640|               Bernd|       null|    null|         1|    4|               <uml>|How do I tag a da...|     6540|
# +----------------+-----------+--------------------+----------+------------+------------------+--------------------+-------------+------+--------------------+--------------------+---------------------+----------------+--------------------+-----------+--------+----------+-----+--------------------+--------------------+---------+
# only showing top 20 rows

# %%
df.registerTempTable("posts")

# %%
sqlContext.sql("""
    SELECT Title, cast(ViewCount as int) FROM posts
    ORDER BY cast(ViewCount as int) DESC
    LIMIT 100
""").show(truncate=False)
# Out:
# +--------------------------------------------------------------------+---------+
# |Title                                                               |ViewCount|
# +--------------------------------------------------------------------+---------+
# |How to undo last commit(s) in Git?                                  |3671106  |
# |Converting String to Int in Java?                                   |3546204  |
# |How to check if one string contains another substring in JavaScript?|3220360  |
# |How to redirect to another page using jQuery?                       |3141591  |
# |How to delete a Git branch both locally and remotely?               |3032622  |
# |How to check if a checkbox is checked in jQuery?                    |2531445  |
# |What is the best comment in source code you have ever encountered?  |2422977  |
# |How to revert Git repository to a previous commit?                  |2413566  |
# |Horizontally center a div in a div                                  |2403840  |
# |How to remove a particular element from an array in JavaScript?     |2376031  |
# |For-each over an array in JavaScript?                               |2358268  |
# |Generating random integers in a specific range                      |2295175  |
# |How to declare an array                                             |2264597  |
# |How to create an HTML button that acts like a link?                 |2221859  |
# |UPDATE from SELECT using SQL Server                                 |2183056  |
# |How can I get query string values in JavaScript?                    |2152548  |
# |Get selected value in dropdown list using JavaScript?               |2090650  |
# |Iterate through a HashMap                                           |2088230  |
# |How to checkout a remote Git branch?                                |2080782  |
# |Check if string contains specific words?                            |2074962  |
# +--------------------------------------------------------------------+---------+
# only showing top 20 rows

# %% [markdown]
# ### Puzzles
#
# 1. List titles of most viewed posts but only having python tag. (may want to see `pypspark.sql.function`)
# 2. Convert approprioate strings into ints and dates.
# 3. Can you find the question that has the most posts attached?? Do the same but use ranking by total score of subposts.
# 4. What else can you find in this data?
